# %%
from google.colab import drive
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import sys

drive.mount("/content/drive")

# !ls /content/drive/My\ Drive/colab/
# !cp /content/drive/My\ Drive/colab/kaggle_setup.py /content/

sys.path.append('/content/drive/My Drive/colab')  # Укажите путь к папке с вашим файлом
from dataset_analysis import explore_dataset  # Импортируйте функцию

# %run kaggle_setup.py
